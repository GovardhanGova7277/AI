# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3

# %% [markdown]
# **Bold Text**

# %% [markdown]
# *Italic text single star*

# %% [markdown]
# > Blockquote

# %% [markdown]
# 1. Ordered list with Number
# 2. Python
# 3. Maths
# 4. Machine Learning
# 5. Deep Learning

# %% [markdown]
# - NLP
# - LLM
# - GEN AI
# - AGENTIC AI
# - ROBOTS

# %% [markdown]
# `code`
# `print(len("Govardhan"))`

# %% [markdown]
# -----------------

# %% [markdown]
# [latexresource](https://www.overleaf.com/learn/latex/Learn_LaTeX_in_30_minutes)

# %% [markdown]
# ![alt text](https://www.shutterstock.com/image-photo/powerful-male-lion-stands-proudly-260nw-2630721775.jpg)

# %% [markdown]
# ## Table
# | Topics | Level |
# | ------ | ----- |
# | Markdown | 4 |
# | Latex | 3 |

# %% [markdown]
# ```
# {
#     "Name":"Govardhan"
#     "Age": 22
#     "Passion": "To Build Something Great"
# }
# ```

# %% [markdown]
# AI
# : Machine which can learn and think like humans

# %% [markdown]
# - [x] Markdown practice
# - [] Latex

# %% [markdown]
# $ E=mc^2 $

# %% [markdown]
# $ a^2 + b^2 = c^2 $

# %% [markdown]
# ```python
# x = 20
# y = 30
#
# ```

# %% [markdown]
# $ (a + b)^2 = a^2 + b^2 + 2ab $

# %% [markdown]
# $$
# slope = \frac{x-y}{x+y}
# $$

# %% [markdown]
# $ a^2 + b^2 = c^2 $

# %% [markdown]
# $x + y = z$

# %% [markdown]
# $ \hat{y} = wx+b $

# %% [markdown]
# $ a^2 + b^2 = c^2 $

# %% [markdown]
# $$
# \frac{1}{2}
# $$

# %% [markdown]
# $$
# E = mc^2 + \frac{a^2 + b^2}{\sqrt{c^2 + d^2}} + \int_{0}^{\infty} x^2 e^{-x} \, dx
# $$

# %% [markdown]
# $$
# f(x) = \sum_{n=1}^{\infty} \frac{1}{n^2} \cdot \frac{\sin(nx)}{x} + \prod_{k=1}^{5} (x + k^2)
# $$

# %% [markdown]
# $$
# A = \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{bmatrix}
# $$

# %% [markdown]
# ## latex pratice
